# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y= make_regression(n_samples=100,n_features =1,noise=20,n_informative=1,n_targets=1)

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([75.84394929])

# %%
lr.intercept_
# Out:
# np.float64(4.22600603126637)

# %%
m = 75.84

# %%
# class GDRegression:
#   def __init__(self,learning_rate,epochs):
#     self.learning_rate = learning_rate
#     self.m = 75.84
#     self.b= -120
#     self.epochs = epochs

#   def fit(self ,x,y):
#     #calculate the b using GD
#     for i in range(self.epochs):
#       loss_slope= -2 * np.sum(y-self.m*x.ravel()-self.b)
#       self.b =self.b-(self.lr * loss_slope)
#       print(loss_slope,self.b)

#       print (self.b)

class GDRegression:
    def __init__(self, learning_rate=0.01, epochs=100):
        self.lr = learning_rate
        self.epochs = epochs
        self.m = 0
        self.b = 0

    def fit(self, x, y):
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m * x.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(loss_slope, self.b)

# %%
gd = GDRegression(0.01, 100)

# %%
gd.fit(x,y)
# Out:
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
# -1992.581083882468 19.925810838824678
# 1992.5810838824684 -7.105427357601002e-15
# -1992.581083882468 19.925810838824674
# 1992.5810838824677 -3.552713678800501e-15
