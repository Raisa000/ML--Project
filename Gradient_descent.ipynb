# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y= make_regression(n_samples=4,n_features =1,noise=80,n_informative=1,n_targets=1,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
#lets apply OLS
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='yellow')

# %%
#let apply gradient descent  assuming slope is constant m= 78.35
#and let's assum the starting value for intercept b=0
y_pred=((78.35*x)+0).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='yellow',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b=0')
plt.legend()
plt.show()

# %%
m=78.35
b=0
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
#let take learing rate =0.1
lr = 0.1

step_size=loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
# calculating the new intercept
b=b-step_size
b
# Out:
# np.float64(62.78329022462765)

# %%
y_pred1=((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='yellow',label='OLS')
plt.plot(x,y_pred1,color='#00a65a',label='b={}'.format(b))
plt.plot(x,y_pred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
#Iteration 2
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(292.98868771492903)

# %%
step_size=loss_slope*lr
step_size
# Out:
# np.float64(-17.579321262895746)

# %%
b= b-step_size
b
# Out:
# np.float64(4.185552681641838)

# %%
y_pred2=((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='yellow',label='OLS')
plt.plot(x,y_pred2,color='#00a65a',label='b={}'.format(b))
plt.plot(x,y_pred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
#Iteration 3
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(-175.79321262895746)

# %%
step_size=loss_slope*lr
step_size
# Out:
# np.float64(-17.579321262895746)

# %%
b= b-step_size
b
# Out:
# np.float64(56.923516470329076)

# %%
y_pred3=((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='yellow',label='OLS')
plt.plot(x,y_pred3,color='#00a65a',label='b={}'.format(b))
plt.plot(x,y_pred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
b= -100
m=78.35
lr=0.1
epochs = 100

for i in range(epochs):
  loss_slope=-2*np.sum(y-m*x.ravel()-b)
  b= b-(lr*loss_slope)
  y_pred=m*x+b
  plt.plot (x,y_pred)
  plt.scatter(x,y)
